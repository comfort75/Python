# %% [markdown]
# # DIABETES ANALYSIS

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# ### Diabetes is a chronic medical condition characterized by elevated levels of blood glucose (sugar) resulting from the body's inability to produce enough insulin or effectively use the insulin it produces.
#
# ### In this analysis, I will be exploring the relationships within a diabetes dataset, investigating key variables such as age, glucose levels, pregnancies, skin thickness, and blood pressure. Through visualizations and statistical examinations, I aim to uncover patterns, correlations, and potential factors influencing the likelihood of diabetes among individuals.

# %% [markdown]
# ## Import all necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\COMFORT\OneDrive\Desktop\diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 213            0      140             65             26      130  42.6
# 38             2       90             68             42        0  38.2
# 516            9      145             88             34      165  30.3
# 537            0       57             60              0        0  21.7
# 420            1      119             88             41      170  45.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 213                     0.431   24        1
# 38                      0.503   27        1
# 516                     0.771   53        1
# 537                     0.735   67        0
# 420                     0.507   26        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %% [markdown]
# ## 1:What is the distribution of the 'Outcome' variable?

# %%
# Plotting the distribution of 'Outcome'
plt.figure(figsize=(8, 6))
df['Outcome'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribution of Outcome')
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Non-Diabetic (0)', 'Diabetic (1)'], rotation=0)
plt.show()

# %% [markdown]
# ## 2:How does the distribution of glucose levels differ between diabetic and non-diabetic individuals?

# %%
# Plotting the distribution of glucose levels for diabetic and non-diabetic individuals
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Glucose', hue='Outcome', kde=True, bins=30, palette=['skyblue', 'salmon'])
plt.title('Distribution of Glucose Levels by Outcome')
plt.xlabel('Glucose Levels')
plt.ylabel('Frequency')
plt.legend(title='Outcome', labels=['Non-Diabetic (0)', 'Diabetic (1)'])
plt.show()

# %% [markdown]
# ## 3:Is there a correlation between BMI and the likelihood of diabetes?

# %%
# Scatter plot of BMI vs. Outcome (diabetic or non-diabetic)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='BMI', y='Outcome', data=df, hue='Outcome', palette=['skyblue', 'salmon'])
plt.title('BMI vs. Diabetes Outcome')
plt.xlabel('BMI')
plt.ylabel('Outcome')
plt.yticks([0, 1], ['Non-Diabetic', 'Diabetic'])
plt.legend(title='Outcome', labels=['Non-Diabetic (0)', 'Diabetic (1)'])
plt.show()

# Calculate correlation coefficient
correlation_coefficient = df['BMI'].corr(df['Outcome'])
print(f"Correlation Coefficient between BMI and Outcome: {correlation_coefficient}")
# Out:
# Correlation Coefficient between BMI and Outcome: 0.2926946626444451

# %% [markdown]
# ## 4:What is the average age of diabetic and non-diabetic individuals?

# %%
# Calculate the mean age for diabetic and non-diabetic individuals
mean_age_diabetic = df[df['Outcome'] == 1]['Age'].mean()
mean_age_non_diabetic = df[df['Outcome'] == 0]['Age'].mean()

print(f"Mean age for diabetic individuals: {mean_age_diabetic:.2f} years")
print(f"Mean age for non-diabetic individuals: {mean_age_non_diabetic:.2f} years")
# Out:
# Mean age for diabetic individuals: 37.07 years
# Mean age for non-diabetic individuals: 31.19 years

# %% [markdown]
# ## 5:What are the descriptive statistics for each variable in the dataset?

# %%
# Display descriptive statistics for each variable
descriptive_stats = df.describe()

# Print the results
print(descriptive_stats)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## 6:How does DiabetesPedigreeFunction correlate with the likelihood of diabetes?

# %%
# Box plot of DiabetesPedigreeFunction by Outcome
plt.figure(figsize=(10, 6))
sns.boxplot(x='Outcome', y='DiabetesPedigreeFunction', data=df, palette=['skyblue', 'salmon'])
plt.title('DiabetesPedigreeFunction by Diabetes Outcome')
plt.xlabel('Outcome')
plt.ylabel('DiabetesPedigreeFunction')
plt.xticks([0, 1], ['Non-Diabetic (0)', 'Diabetic (1)'])
plt.show()

# %% [markdown]
# ## 7:How is the age distribution in the dataset? Is there a specific age group more prone to diabetes?

# %%
# Set up the figure
plt.figure(figsize=(10, 6))

# Plot the age distribution for both diabetic and non-diabetic individuals
sns.histplot(data=df, x='Age', hue='Outcome', kde=True, bins=30, palette=['skyblue', 'salmon'])
plt.title('Age Distribution by Diabetes Outcome')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Outcome', labels=['Non-Diabetic (0)', 'Diabetic (1)'])
plt.show()

# %% [markdown]
# ## 8:Is there an association between age and glucose levels?

# %%
# Regression plot of Age vs. Glucose with a linear fit
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Glucose', data=df, scatter_kws={'s': 10}, line_kws={'color': 'red'})
plt.title('Regression Plot of Age vs. Glucose')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.show()

# %% [markdown]
# ### IN CONCLUSION

# %% [markdown]
# ### In conclusion, this analysis of the diabetes dataset has revealed valuable insights into the relationships among key variables such as age, glucose levels, pregnancies, skin thickness, and blood pressure. Through visualizations and statistical examinations, patterns and correlations were explored, shedding light on potential factors influencing the likelihood of diabetes.

# %% [markdown]
# # THANK YOU
